# %%
import pandas as pd
df = pd.read_csv("pokemon_data.csv")

df_xlsx = pd.read_excel("pokemon_data.xlsx")
print(df)
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9      7                   Squirtle     Water     NaN   44      48       65
# 10     8                  Wartortle     Water     NaN   59      63       80
# ...

# %%
print(df.head(3))
print(df_xlsx.head(3))

print(df.tail(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# ...

# %%
# df = pd.read_csv("pokemon_data.txt")
# All the data will be printed as one colomon
df = pd.read_csv("pokemon_data.txt",delimiter="\t")
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Read Data in Pandas

# %%
## Read Headers
print(df.columns)

## Read Each Column
print(df["Name"][0:5])
print(df[["Name", "Type 1", "HP"]])

## Read Each Row
print(df.head(4)) # The first 4 rows
print(df.iloc[1]) # Get the 2nd row
print(df.iloc[1:4]) # Get the 2nd - 5th row


## Read a specific location (R,C)
print(df.iloc[2,1])  # [col,row] col not counting the categories(first row) and index(first col)
print(df.iloc[1,1])  # [col,row]
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object
#                           Name    Type 1   HP
# 0                    Bulbasaur     Grass   45
# 1                      Ivysaur     Grass   60
# 2                     Venusaur     Grass   80
# 3        VenusaurMega Venusaur     Grass   80
# 4                   Charmander      Fire   39
# 5                   Charmeleon      Fire   58
# 6                    Charizard      Fire   78
# 7    CharizardMega Charizard X      Fire   78
# 8    CharizardMega Charizard Y      Fire   78
# 9                     Squirtle     Water   44
# 10                   Wartortle     Water   59
# 11                   Blastoise     Water   79
# ...

# %%
df.loc[df["Type 1"]=="Fire"] # Get the info based on complex condition
df.loc[df["Type 1"]=="Grass"] # Get the info based on complex condition
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1                Bulbasaur  Grass    Poison   45      49       49
# 1      2                  Ivysaur  Grass    Poison   60      62       63
# 2      3                 Venusaur  Grass    Poison   80      82       83
# 3      3    VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                   Oddish  Grass    Poison   45      50       55
# 49    44                    Gloom  Grass    Poison   60      65       70
# 50    45                Vileplume  Grass    Poison   75      80       85
# 75    69               Bellsprout  Grass    Poison   50      75       35
# 76    70               Weepinbell  Grass    Poison   65      90       50
# 77    71               Victreebel  Grass    Poison   80     105       65
# 110  102                Exeggcute  Grass   Psychic   60      40       80
# 111  103                Exeggutor  Grass   Psychic   95      95       85
# ...

# %% [markdown]
# ### Sorting/Describing Data

# %%
# df.describe() # Get a description of some common data(count,mean,std,min,percentile)
# stemmer # Ascending: 升序
df.sort_values(["Type 1","HP"],ascending = [1,0]) # Define which one to be ascending
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 447  402               Kricketune    Bug       NaN  77      85       51
# 220  205               Forretress    Bug     Steel  75      90      140
# 602  542                 Leavanny    Bug     Grass  75     103       80
# 717  649                 Genesect    Bug     Steel  71     120       95
# 54    49                 Venomoth    Bug    Poison  70      65       60
# 132  123                  Scyther    Bug    Flying  70     110       80
# ...

# %% [markdown]
# ### Making changes to the data

# %%
# df['Total'] = df["HP"] + df["Attack"]
# df = df.drop(columns = ['Total'])

df['total'] = df.iloc[:,4:9].sum(axis=1)

cols = list(df.columns)
print(cols[0:4])
print([cols[-1]])
print(cols[4:12])

df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
# Change the order of the columns
# Using number as index here is actually a bit dangerous
# especially when the data is changing. 

df.head(5)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2']
# ['Legendary']
# ['total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']
#    #                   Name Type 1  Type 2  Legendary  total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False    481  45      49
# 1  2                Ivysaur  Grass  Poison      False    610  60      62
# 2  3               Venusaur  Grass  Poison      False    790  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False    970  80     100
# 4  4             Charmander   Fire     NaN      False    438  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %% [markdown]
# ### Save Changes to Data Frame

# %%
# df.to_csv("modified.csv",index=False)
df.to_excel("modifed.xlsx",index =False)
df.to_csv("modifed.txt",index=False,sep = '\t')

# %% [markdown]
# ### Filtering Data

# %%
new_df = df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df["HP"] > 70)]
# AND:& OR:| ↑-Almost the same as SQL Command
# new_df.to_csv("filtered.csv")
new_df = new_df.reset_index()
new_df = new_df.reset_index(drop = False)
# new_df.reset_index(drop = False,inplace =True) #By doing this, don't need to assign the data to a new variable
new_df
# Out:
#    index    #                   Name Type 1  Type 2  Legendary  total   HP  \
# 0      2    3               Venusaur  Grass  Poison      False    790   80
# 1      3    3  VenusaurMega Venusaur  Grass  Poison      False    970   80
# 2     50   45              Vileplume  Grass  Poison      False    790   75
# 3     77   71             Victreebel  Grass  Poison      False    770   80
# 4    652  591              Amoonguss  Grass  Poison      False    788  114
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      82       83      100      100     80           1
# 1     100      123      122      120     80           1
# 2      80       85      110       90     50           1
# 3     105       65      100       70     70           1
# 4      85       70       85       80     30           5

# %%
# df.loc[df["Name"].str.contains("Mega")]
# df.loc[-df["Name"].str.contains("Mega")]
# "-" means not
# This can also pass in regular expression or other complecated forms

import re
# df.loc[df["Type 1"].str.contains("Fire|Grass", flags = re.I, regex = True)]
# re.I : ignore case 忽略大小写

df.loc[df["Name"].str.contains("^pi[a-z]*",flags = re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary  total   HP  \
# 20    16               Pidgey    Normal    Flying      False    355   40
# 21    17            Pidgeotto    Normal    Flying      False    506   63
# 22    18              Pidgeot    Normal    Flying      False    686   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False    836   83
# 30    25              Pikachu  Electric       NaN      False    410   35
# 136  127               Pinsir       Bug       NaN      False    760   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False    900   65
# 186  172                Pichu  Electric       NaN      False    255   20
# 219  204               Pineco       Bug       NaN      False    515   50
# 239  221            Piloswine       Ice    Ground      False    740  100
# 438  393               Piplup     Water       NaN      False    492   53
# 558  499              Pignite      Fire  Fighting      False    671   90
# ...

# %% [markdown]
# ### Condition Changes

# %%
df.loc[df["Type 1"] == "Flamer","Type 1"] = "Fire"
df = pd.read_csv("modified.csv")

# %% [markdown]
# ### Conditional Changes

# %%
# df.loc[df["total"] > 500, ["Generation","Legendary"]] = ["Test 1", "Test 2"]
# df

df = pd.read_csv("modified.csv")
df
# Out:
#        #                       Name    Type 1  Type 2  Legendary  total   HP  \
# 0      1                  Bulbasaur     Grass  Poison      False    481   45
# 1      2                    Ivysaur     Grass  Poison      False    610   60
# 2      3                   Venusaur     Grass  Poison      False    790   80
# 3      3      VenusaurMega Venusaur     Grass  Poison      False    970   80
# 4      4                 Charmander      Fire     NaN      False    438   39
# 5      5                 Charmeleon      Fire     NaN      False    585   58
# 6      6                  Charizard      Fire  Flying      False    783   78
# 7      6  CharizardMega Charizard X      Fire  Dragon      False    983   78
# 8      6  CharizardMega Charizard Y      Fire  Flying      False    953   78
# 9      7                   Squirtle     Water     NaN      False    478   44
# 10     8                  Wartortle     Water     NaN      False    614   59
# ...

# %% [markdown]
# ### Aggregate Statics(Groupby)

# %%
df = pd.read_csv("modified.csv")
# df.groupby(["Type 1"]).mean().sort_values("Defense",ascending=False)
df.groupby(["Type 1"]).sum()
df.groupby(["Type 1"]).count()
# Out:
#             #  Name  Type 2  Legendary  total   HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug        69    69      52         69     69   69      69       69       69
# Dark       31    31      21         31     31   31      31       31       31
# Dragon     32    32      21         32     32   32      32       32       32
# Electric   44    44      17         44     44   44      44       44       44
# Fairy      17    17       2         17     17   17      17       17       17
# Fighting   27    27       7         27     27   27      27       27       27
# Fire       52    52      24         52     52   52      52       52       52
# Flying      4     4       2          4      4    4       4        4        4
# Ghost      32    32      22         32     32   32      32       32       32
# Grass      70    70      37         70     70   70      70       70       70
# Ground     32    32      19         32     32   32      32       32       32
# ...
